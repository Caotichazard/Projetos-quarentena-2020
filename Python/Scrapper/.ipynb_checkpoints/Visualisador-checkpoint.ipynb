# %%
import ploter

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as dt

# %%
nomes = ploter.read_from_meta()

# %%
print(nomes)
# Out:
# ['SSDKingstonA400240GBSATALeitura500MBsGravação350MBsSA400S37240G', 'SSDKingstonA400480GBSATALeitura500MBsGravação450MBsSA400S37480G', 'SSDKingstonA400120GBSATALeitura500MBsGravação320MBsSA400S37120G', 'SSDCrucialBX500240GBSATALeitura540MBsGravação500MBsCT240BX500SSD1', 'SSDLexarNS100256GBSATALeitura520MBsLNS100256RB', 'SSDCrucialBX500120GBSATALeitura540MBsGravação500MBsCT120BX500SSD1', 'SSDWDGreen240GBSATALeitura545MBsGravação465MBsWDS240G2G0A', 'SSDWDGreen120GBSATALeitura545MBsGravação430MBsWDS120G2G0A', 'SSDWDGreen480GBSATALeitura545MBsGravação430MBsWDS480G2G0A', 'SSDAdataSU650240GBSATALeitura520MBsGravação450MBsASU650SS240GTR', 'SSDAdataSU650120GBSATALeitura520MBsGravação450MBsASU650SS120GTR', 'SSDSandiskPlus120GBSATALeitura530MBsGravação310MBsSDSSDA120GG27', 'SSDSandiskPlus480GBSATALeitura535MBsGravação445MBsSDSSDA480GG26', 'SSDSandiskPlus240GBSATALeitura530MBsGravação440MBsSDSSDA240GG26', 'SSDAdataSU650480GBSATALeitura520MBsGravação450MBsASU650SS480GTR', 'SSDGigabyte240GBSATALeitura500MBsGravação420MBsGPGSTFS31240GNTD', 'SSDLexarNS100128GBSATALeitura520MBsLNS100128RBNA', 'SSDPNYCS900120GBSATALeitura515MBsGravação490MBsSSD7CS900120RB', 'SSDGigabyte120GBSATALeitura500MBsGravação380MBsGPGSTFS31120GNTD', 'SSDAdataSU630480GBSATALeitura520MBsGravação450MBsASU630SS480GQR', 'SSDCrucialMX500250GBSATALeitura560MBsGravação510MBsCT250MX500SSD1', 'SSDAdataUltimateSU800256GBSATALeituras550MBseGravações500MBsASU800SS256GTC', 'SSDGigabyteUDPro256GBSATALeitura530MBsGravação500MBsGPGSTFS30256GTTD', 'SSDWDBlue250GBSATALeitura550MBsGravação525MBsWDS250G2B0A', 'SSDAdataSU630240GBSATALeitura520MBsGravação450MBsASU630SS240GQR', 'SSDGigabyte256GBSATALeituras520MbseGravações500MbsGPGSTFS31256GTND', 'SSDWDBlue500GBSATALeitura560MBsGravação530MBsWDS500G2B0A', 'SSDAdataSU635240GBSATALeituras520MBseGravações450MBsASU635SS240GQR', 'SSDAdataSU635480GBSATALeituras520MBseGravações450MBsASU635SS480GQR', 'SSDKingston25120GBV300SATAIIILeituras450MBseEscritas450MBsSV300S37A120G', 'MemóriaHyperXFury8GB2666MHzDDR4CL16PretoHX426C16FB38', 'MemóriaXPGGammixD308GB2666MhzDDR4CL16AX4U266638G16SB30', 'MemóriaCorsairVengeanceLPX8GB2666MHzDDR4C16PretoCMK8GX4M1A2666C16', 'MemóriaHPV28GB2666MhzDDR4CL197EH55AAABM', 'MemóriaHyperXFuryRGB8GB2666MHzDDR4CL16PretoHX426C16FB3A8', 'MemóriaHyperXFury8GB2x4GB2666MHzDDR4CL16PretoHX426C16FB3K28', 'MemóriaPatriotViperSteel8GB1x8GB2666MHzDDR4pNotebookCL18PVS48G266C8S', 'MemóriaXPGSpectrixD41RGB8GB2666MHzDDR4CL16CinzaAX4U266638G16ST41', 'MemóriaCorsairVengeanceParaNotebook8GB2666MhzDDR4C18CMSX8GX4M1A2666C18', 'MemóriaCorsairVengeanceLPX8GB2x4GB2666MhzDDR4C16BlackCMK8GX4M2A2666C16', 'MemóriaXPGSpectrixD41RGB8GB2666MHzDDR4CL16VermelhoAX4U266638G16SR41', 'MemóriaBluecaseRGB8GB2666MHzDDR4CL16BMGLR4D26M12VM168G', 'MemóriaPatriotViperElite8GB2x4GB2666MHzDDR4CL16CinzaPVE48G266C6KGY', 'MemóriaHyperXImpact8GB2666MHzDDR4NotebookCL15PretoHX426S15IB28', 'MemóriaCorsair8GB2666MHzDDR4C18CMV8GX4M1A2666C18', 'MemóriaKingston8GB2666MHzDDR4CL19KVR26N19S88', 'MemóriaLexar8GB2666MHzDDR4CL19paraNotebookLD4AS008GR2666G', 'MemóriaLexar8GB2666MHzDDR4CL19LD4AU008GR2666G', 'MemóriaHusky8GB2666MhzDDR4CL19PretoHMRD4826', 'MemóriaXPGHunter8GB2666MHzDDR4CL16AX4U266638G16SBHT', 'MemóriaHPS18GB2666MhzDDR4CL197EH98AAABM', 'MemóriaPatriotViperElite8GB1x8GB2666MHzDDR4CL16CinzaPVE48G266C6GY', 'MemóriaXPGHunter8GB2666MHzDDR4CL18AX4S266638G18SBHT', 'MemóriaHPV68GB2666MhzDDR4CL18Vermelho7EH61AAABM', 'MemóriaCorsairVengeanceLPX8GB2666MHzDDR4CL16VermelhoCMK8GX4M1A2666C16R', 'MemóriaCrucialBallistixSportLT8GB2666MHzDDR4CL16VermelhoBLS8G4D26BFSEK', 'MemóriaCrucialBallistixSportLT8GB2666MHzDDR4CinzaBLS8G4D26BFSBK', 'MemóriaXPGGammixD308GB2666MHzDDR4CL16VermelhoAX4U266638G16SR30', 'SSDCrucialBX500480GBSATALeitura540MBsGravação500MBsCT480BX500SSD1', 'SSDPNYCS900480GBSATA25Leituras550MBseGravações500MBsSSD7CS900480RB']

# %%
precos,datas,nome_prod,tracking = ploter.read_from_prod(nomes[1])
print(datas)
if tracking:
    plt.plot(dt.date2num(datas),precos)
    plt.gcf().autofmt_xdate()
    plt.title(nome_prod)
    plt.show()
# Out:
# [datetime.datetime(2020, 9, 2, 0, 0), datetime.datetime(2020, 9, 3, 0, 0), datetime.datetime(2020, 9, 4, 0, 0), datetime.datetime(2020, 9, 5, 0, 0), datetime.datetime(2020, 9, 6, 0, 0), datetime.datetime(2020, 9, 7, 0, 0), datetime.datetime(2020, 9, 7, 0, 0), datetime.datetime(2020, 9, 7, 0, 0), datetime.datetime(2020, 9, 7, 0, 0), datetime.datetime(2020, 9, 7, 0, 0), datetime.datetime(2020, 9, 7, 0, 0), datetime.datetime(2020, 9, 9, 0, 0), datetime.datetime(2020, 9, 10, 0, 0), datetime.datetime(2020, 9, 11, 0, 0), datetime.datetime(2020, 9, 11, 0, 0)]

# %%
precos,datas,nome_prod,tracking = ploter.read_from_prod(nomes[2])
plt.plot(datas,precos)
plt.title(nome_prod)
plt.show()

# %%
for nome in nomes:
    precos,datas,nome_prod,tracking = ploter.read_from_prod(nome)
    if tracking:
        plt.plot(datas,precos)
        plt.title(nome_prod)
        plt.show()
